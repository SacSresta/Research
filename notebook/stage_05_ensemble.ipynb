# %%
from data_pipeline.stage_02.merger import merge_data

# %%
df  = merge_data(start_date='2015-01-01')
# Out:
# Same date as previous batch: 2015-01-12
# Fetching next batch starting from: 2015-01-12
# Same date as previous batch: 2015-01-15
# Fetching next batch starting from: 2015-01-15
# Same date as previous batch: 2015-01-26
# Fetching next batch starting from: 2015-01-26
# Same date as previous batch: 2015-01-27
# Fetching next batch starting from: 2015-01-27
# Fetching next batch starting from: 2015-01-28
# Same date as previous batch: 2015-02-01
# Fetching next batch starting from: 2015-02-01
# Same date as previous batch: 2015-02-09
# Fetching next batch starting from: 2015-02-09
# Same date as previous batch: 2015-02-11
# Fetching next batch starting from: 2015-02-11
# Same date as previous batch: 2015-02-17
# Fetching next batch starting from: 2015-02-17
# Same date as previous batch: 2015-02-22
# Fetching next batch starting from: 2015-02-22
# Same date as previous batch: 2015-02-26
# Fetching next batch starting from: 2015-02-26
# Same date as previous batch: 2015-03-03
# ...

# %%
df.headline.isnull().sum()
# Out:
# np.int64(0)

# %%
# Fill null headlines with a placeholder
data = df['headline'].fillna("No headline available")

# %%
data.isnull().sum()
# Out:
# np.int64(0)
