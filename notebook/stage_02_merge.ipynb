# %%
from data_pipeline.stage_01 import news_collector
from data_pipeline.stage_01.historical_data import fetch_market_data
from data_pipeline.stage_01.news_collector import fetch_news_df
from data_pipeline.stage_01 import historical_data

# %%
news_df = fetch_news_df(symbol='AAPL',start_date='2025-01-01')
# Out:
# Same date as previous batch: 2025-01-07
# Fetching next batch starting from: 2025-01-07
# Same date as previous batch: 2025-01-15
# Fetching next batch starting from: 2025-01-15
# Same date as previous batch: 2025-01-21
# Fetching next batch starting from: 2025-01-21
# Same date as previous batch: 2025-01-24
# Fetching next batch starting from: 2025-01-24
# Same date as previous batch: 2025-01-29
# Fetching next batch starting from: 2025-01-29
# Same date as previous batch: 2025-01-31
# Fetching next batch starting from: 2025-01-31
# Same date as previous batch: 2025-02-03
# Fetching next batch starting from: 2025-02-03
# Same date as previous batch: 2025-02-08
# Fetching next batch starting from: 2025-02-08
# Same date as previous batch: 2025-02-14
# Fetching next batch starting from: 2025-02-14
# Same date as previous batch: 2025-02-19
# Fetching next batch starting from: 2025-02-19
# Same date as previous batch: 2025-02-24
# Fetching next batch starting from: 2025-02-24
# ...

# %%
market_df = fetch_market_data(ticker='AAPL', start_date='2025-01-01', end_date='2025-03-17')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
market_df
# Out:
# Price       Date   Adj Close       Close        High         Low        Open  \
# 0     2025-01-02  243.582199  243.850006  249.100006  241.820007  248.929993
# 1     2025-01-03  243.092728  243.360001  244.179993  241.889999  243.360001
# 2     2025-01-06  244.730927  245.000000  247.330002  243.199997  244.309998
# 3     2025-01-07  241.944000  242.210007  245.550003  241.350006  242.979996
# 4     2025-01-08  242.433441  242.699997  243.710007  240.050003  241.919998
# 5     2025-01-10  236.589874  236.850006  240.160004  233.000000  240.009995
# 6     2025-01-13  234.142563  234.399994  234.669998  229.720001  233.529999
# 7     2025-01-14  233.023788  233.279999  236.119995  232.470001  234.750000
# 8     2025-01-15  237.608749  237.869995  238.960007  234.429993  234.639999
# 9     2025-01-16  228.009308  228.259995  238.009995  228.029999  237.350006
# 10    2025-01-17  229.727417  229.979996  232.289993  228.479996  232.119995
# ...

# %%
news_df
# Out:
#    Ticker        Date                                           headline
# 0    AAPL  2025-01-01  EXCLUSIVE: Top 20 Most-Searched Tickers On Ben...
# 1    AAPL  2025-01-02  Tim Cook, Mark Zuckerberg, Elon Musk, And More...
# 2    AAPL  2025-01-03  Biden-Era Net Neutrality Rules Overturned By F...
# 3    AAPL  2025-01-04  Apple CEO Tim Cook Reportedly Donates $1 Milli...
# 4    AAPL  2025-01-05  iPhone 17 Leak, Tim Cook's Donation To Trump I...
# ..    ...         ...                                                ...
# 70   AAPL  2025-03-13  Rise Of DeepSeek And Trump Tariff Threats Hurt...
# 71   AAPL  2025-03-14  Ross Gerber Finds Tesla Stock Expensive Despit...
# 72   AAPL  2025-03-15  Apple Reportedly Fights UK Government's 'Unacc...
# 73   AAPL  2025-03-16  Apple's Secretive UK Court Hearing, Metallica ...
# 74   AAPL  2025-03-17  Trump Trade Policy A 'Big Headache' For Custom...
#
# [75 rows x 3 columns]

# %%
print(market_df.columns)
print(news_df.columns)
# Out:
# Index(['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')
# Index(['Ticker', 'Date', 'headline'], dtype='object')

# %%
import pandas as pd
market_df['Date'] = pd.to_datetime(market_df['Date'])
news_df['Date'] = pd.to_datetime(news_df['Date'])

# %%
merged_df = pd.merge(
    market_df,
    news_df,
    on='Date',
    how='inner'
)

# %%
merged_df.head(2)
# Out:
#         Date   Adj Close       Close        High         Low        Open  \
# 0 2025-01-02  243.582199  243.850006  249.100006  241.820007  248.929993
# 1 2025-01-03  243.092728  243.360001  244.179993  241.889999  243.360001
#
#      Volume Ticker                                           headline
# 0  55740700   AAPL  Tim Cook, Mark Zuckerberg, Elon Musk, And More...
# 1  40244100   AAPL  Biden-Era Net Neutrality Rules Overturned By F...
