# %%
from datetime import datetime
from lumibot.backtesting import YahooDataBacktesting
from lumibot.strategies import Strategy

# A simple strategy that buys AAPL on the first day and holds it
class MyStrategy(Strategy):
    def on_trading_iteration(self):
        if self.first_iteration:
            aapl_price = self.get_last_price("AAPL")
            quantity = self.portfolio_value // aapl_price
            order = self.create_order("AAPL", quantity, "buy")
            self.submit_order(order)

# Pick the dates that you want to start and end your backtest
backtesting_start = datetime(2020, 11, 1)
backtesting_end = datetime(2020, 12, 31)

# Run the backtest
MyStrategy.backtest(
    YahooDataBacktesting,
    backtesting_start,
    backtesting_end,
)
# Out:
# 2025-05-26 06:38:31 | lumibot.credentials | WARNING | No .env file found. This is ok if you are using environment variables or secrets (like on Replit, AWS, etc), but if you are not, please create a .env file in the root directory of the project.
# 2025-05-26 06:38:31 | asyncio | INFO | [unknown] Waiting for the socket stream connection to be established,
#                 method _stream_established must be called
# 2025-05-26 06:38:31 | alpaca.trading.stream | INFO | started trading stream
# 2025-05-26 06:38:31 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:32 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:32 | alpaca.trading.stream | INFO | starting trading websocket connection
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 from datetime import datetime
# ----> 2 from lumibot.backtesting import YahooDataBacktesting
#       3 from lumibot.strategies import Strategy
#       5 # A simple strategy that buys AAPL on the first day and holds it
#
# File c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\lumibot\backtesting\__init__.py:6
#       4 from .backtesting_broker import BacktestingBroker
#       5 from .pandas_backtesting import PandasDataBacktesting
# ----> 6 from .polygon_backtesting import PolygonDataBacktesting
#       7 from .thetadata_backtesting import ThetaDataBacktesting
#       8 from .yahoo_backtesting import YahooDataBacktesting
#
# File c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\lumibot\backtesting\polygon_backtesting.py:13
#      11 from lumibot.data_sources import PandasData
#      12 from lumibot.entities import Asset, Data
# ---> 13 from lumibot.tools import polygon_helper
#      14 from lumibot.tools.polygon_helper import PolygonClient
#      16 START_BUFFER = timedelta(days=5)
#
# File c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\lumibot\tools\polygon_helper.py:27
#      25 from lumibot.entities import Asset
#      26 from lumibot import LUMIBOT_DEFAULT_PYTZ
# ---> 27 from lumibot.credentials import POLYGON_API_KEY
#      29 # Adjust as desired, in days. We'll reuse any existing chain file
#      30 # that is not older than RECENT_FILE_TOLERANCE_DAYS.
#      31 RECENT_FILE_TOLERANCE_DAYS = 14
#
# File c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\lumibot\credentials.py:330
#     327 else:
#     328     # Auto-detect broker based on available credentials if not explicitly specified
#     329     if ALPACA_CONFIG["API_KEY"]:
# --> 330         broker = Alpaca(ALPACA_CONFIG)
#     331     elif TRADIER_CONFIG["ACCESS_TOKEN"]:
#     332         broker = Tradier(TRADIER_CONFIG)
#
# File c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\lumibot\brokers\alpaca.py:139, in Alpaca.__init__(self, config, max_workers, chunk_size, connect_stream, data_source)
#     130     data_source = AlpacaData(config, max_workers=max_workers, chunk_size=chunk_size)
#     131 super().__init__(
#     132     name="alpaca",
#     133     connect_stream=connect_stream,
#    (...)
#     136     max_workers=max_workers,
#     137 )
# --> 139 self.api = TradingClient(self.api_key, self.api_secret, paper=self.is_paper)
#
# File c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\client.py:74, in TradingClient.__init__(self, api_key, secret_key, oauth_token, paper, raw_data, url_override)
#      53 def __init__(
#      54     self,
#      55     api_key: Optional[str] = None,
#    (...)
#      60     url_override: Optional[str] = None,
#      61 ) -> None:
#      62     """
#      63     Instantiates a client for trading and managing personal brokerage accounts.
#      64
#    (...)
#      72         url_override (Optional[str]): If specified allows you to override the base url the client points to for proxy/testing.
#      73     """
# ---> 74     super().__init__(
#      75         api_key=api_key,
#      76         secret_key=secret_key,
#      77         oauth_token=oauth_token,
#      78         api_version="v2",
#      79         base_url=(
#      80             url_override
#      81             if url_override
#      82             else BaseURL.TRADING_PAPER if paper else BaseURL.TRADING_LIVE
#      83         ),
#      84         sandbox=paper,
#      85         raw_data=raw_data,
#      86     )
#
# File c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\common\rest.py:61, in RESTClient.__init__(self, base_url, api_key, secret_key, oauth_token, use_basic_auth, api_version, sandbox, raw_data, retry_attempts, retry_wait_seconds, retry_exception_codes)
#      29 def __init__(
#      30     self,
#      31     base_url: Union[BaseURL, str],
#    (...)
#      41     retry_exception_codes: Optional[List[int]] = None,
#      42 ) -> None:
#      43     """Abstract base class for REST clients. Handles submitting HTTP requests to
#      44     Alpaca API endpoints.
#      45
#    (...)
#      58         retry_exception_codes (Optional[List[int]]): The API exception codes to retry a request on.
#      59     """
# ---> 61     self._api_key, self._secret_key, self._oauth_token = self._validate_credentials(
#      62         api_key=api_key, secret_key=secret_key, oauth_token=oauth_token
#      63     )
#      64     self._api_version: str = api_version
#      65     self._base_url: Union[BaseURL, str] = base_url
#
# File c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\common\rest.py:362, in RESTClient._validate_credentials(api_key, secret_key, oauth_token)
#     357     raise ValueError(
#     358         "Either an oauth_token or an api_key may be supplied, but not both"
#     359     )
#     361 if not oauth_token and not (api_key and secret_key):
# --> 362     raise ValueError(
#     363         "A corresponding secret_key must be supplied with the api_key"
#     364     )
#     366 return api_key, secret_key, oauth_token
#
# ValueError: A corresponding secret_key must be supplied with the api_key
# 2025-05-26 06:38:34 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:34 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:36 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:36 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:37 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:37 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:39 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:39 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:40 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:42 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:43 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:43 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:45 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:45 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:46 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:48 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:49 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:49 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:51 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:51 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:53 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:54 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:54 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:55 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:55 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:57 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:57 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:38:58 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:38:58 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:00 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:00 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:01 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:01 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:03 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:03 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:04 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:04 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:06 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:06 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:07 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:07 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:09 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:09 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:10 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:10 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:12 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:12 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:13 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:13 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:15 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:15 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:16 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:16 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:18 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:18 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:19 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:19 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:21 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:21 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:22 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:22 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:24 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:24 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:25 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:25 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:26 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:26 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:28 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:28 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:29 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:39:29 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:31 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:31 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:33 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:33 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:34 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:34 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:36 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:39:36 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:37 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:37 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:39 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:39 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:40 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:40 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:41 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:43 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:43 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:44 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:46 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:46 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:47 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:49 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:49 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:50 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:52 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:52 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:53 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:55 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:55 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:56 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:56 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:58 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:39:58 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:39:59 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
# ...
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:27 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:29 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:44:29 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:30 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:30 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:32 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:44:32 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:33 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:33 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:35 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:35 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:36 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:36 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:38 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:38 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:39 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:39 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:41 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:44:41 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:42 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:44:42 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:44 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:44 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:45 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:45 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:47 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:44:47 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:48 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:48 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:50 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:50 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:51 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:51 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:53 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:44:53 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:54 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:54 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:56 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:56 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:57 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:44:57 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:44:59 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:44:59 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:45:00 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:45:00 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:45:02 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:45:02 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:45:03 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:45:03 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:45:05 | alpaca.trading.stream | WARNING | trading stream websocket error, restarting  connection: server rejected WebSocket connection: HTTP 429
# 2025-05-26 06:45:05 | alpaca.trading.stream | INFO | starting trading websocket connection
# 2025-05-26 06:45:06 | alpaca.trading.stream | ERROR | error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "c:\Users\sachi\Documents\Researchcode\research\lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# 2025-05-26 06:45:06 | alpaca.trading.stream | INFO | starting trading websocket connection
