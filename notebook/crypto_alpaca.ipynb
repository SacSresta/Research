# %%
from alpaca.data.historical import CryptoHistoricalDataClient

# %%
from alpaca.trading.requests import MarketOrderRequest

# %%
from alpaca.broker.requests import

# %%
from alpaca_trade_api.rest import REST
from dotenv import load_dotenv
import os
load_dotenv()
# Replace with your actual API keys
API_KEY = os.getenv('ALPACA_API_KEY') 
SECRET_KEY = os.getenv('ALPACA_SECRET_KEY')
BASE_URL = 'https://paper-api.alpaca.markets'  # or use live URL for live trading

api = REST(API_KEY, SECRET_KEY, BASE_URL)

# Get all active and tradable assets
assets = api.list_assets()

# Filter for only tradable symbols
tradable_assets = [asset for asset in assets if asset.tradable]

list_og_Asset = []
# Print some tradable symbols
for asset in tradable_assets:
    list_og_Asset.append(asset.symbol)

# %%
api.list_assets()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 api.get_asset()
#
# TypeError: REST.get_asset() missing 1 required positional argument: 'symbol'

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetAssetsRequest
from alpaca.trading.enums import AssetClass
from alpaca.trading.client import TradingClient
import pandas as pd
api = 'PKY7ODAXYMWTX4JK7DVR'
secret = 'yvQclRacekxCgwL0KX70SFkdbBAsVRvrBQnYaYGY'
BASE_URL = 'https://paper-api.alpaca.markets'
# paper=True enables paper trading
trading_client = TradingClient(api, secret, paper=True)
search_params = GetAssetsRequest(asset_class=AssetClass.CRYPTO)

assets = trading_client.get_all_assets(search_params)

# %%
cryptos = []
for asset in assets:

    cryptos.append(asset.__dict__['symbol'])

# %%
cryptos[12]
# Out:
# 'BCH/BTC'

# %%
import yfinance as yf

# %%
yf.download('BTCUSD')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BTCUSD']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [(Adj Close, BTCUSD), (Close, BTCUSD), (High, BTCUSD), (Low, BTCUSD), (Open, BTCUSD), (Volume, BTCUSD)]
# Index: []

# %%
list_og_Asset
# Out:
# ['DFII',
#  'DFIP',
#  'DFJ',
#  'DFLI',
#  'DFLIW',
#  'DFLV',
#  'DFND',
#  'DFNL',
#  'DFP',
#  'DFSB',
#  'DFSE',
#  'DFSI',
#  'DFSU',
#  'DFVE',
#  'DFVX',
#  'DGCB',
#  'DGICB',
#  'DGP',
#  'DGRE',
#  'DGT',
#  'DGXX',
#  'DGZ',
#  'DHAI',
#  'DHAIW',
#  'DHCNI',
#  'DHCNL',
#  'DHDG',
#  'DHF',
#  'DHSB',
#  'DHX',
#  'DHY',
#  'DIAX',
#  'DIEM',
#  'DIHP',
#  'DIM',
#  'DINT',
#  'DIPS',
#  'DIST',
#  'DISTR',
#  'DISTW',
#  'DIT',
#  'DIV',
#  'DIVB',
#  'DIVD',
#  'DIVG',
#  'DIVI',
#  'DIVL',
#  'DIVP',
#  'DIVS',
#  'DIVY',
#  'DIVZ',
#  'DJAN',
#  'DJD',
#  'DJIA',
#  'DJP',
#  'DJTU',
#  'DJTWW',
#  'DJUL',
#  'DJUN',
#  'DLLL',
#  'DLN',
#  'DLNG.PRA',
#  'DLNG.PRB',
#  'DLPN',
#  'DLR.PRJ',
#  'DLR.PRK',
#  'DLR.PRL',
#  'DLS',
#  'DMAA',
#  'DMAAR',
#  'DMAAU',
#  'DMAR',
#  'DMAT',
#  'DMAX',
#  'DMAY',
#  'DMB',
#  'DMBS',
#  'DMCY',
#  'DMF',
#  'DMO',
#  'DMX',
#  'DMXF',
#  'DMYY',
#  'DMYY.U',
#  'DMYY.WS',
#  'DNA',
#  'DNL',
#  'DNOV',
#  'DOCT',
# ...
